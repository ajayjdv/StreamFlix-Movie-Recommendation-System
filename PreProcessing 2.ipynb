# %%
import pandas as pd
import numpy as np

# %%
credits =  pd.read_csv('credits.csv')

# %%
credits
# Out:
#                                                                              cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)', 'credit_id': '52fe4284c3...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', 'credit_id': '52fe44bfc3a3...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'credit_id': '52fe466a92514...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah' Jackson", 'credit_id': ...
# 4      [{'cast_id': 1, 'character': 'George Banks', 'credit_id': '52fe44959251...
# ...                                                                           ...
# 45471  [{'cast_id': 0, 'character': '', 'credit_id': '5894a909925141427e0079a5...
# 45472  [{'cast_id': 1002, 'character': 'Sister Angela', 'credit_id': '52fe4af1...
# 45473  [{'cast_id': 6, 'character': 'Emily Shaw', 'credit_id': '52fe4776c3a368...
# 45474  [{'cast_id': 2, 'character': '', 'credit_id': '52fe4ea59251416c7515d7d5...
# 45475                                                                          []
#
#                                                                              crew  \
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'department': 'Directing', '...
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'department': 'Production', ...
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'department': 'Directing', '...
# 3      [{'credit_id': '52fe44779251416c91011acb', 'department': 'Directing', '...
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'department': 'Sound', 'gend...
# ...                                                                           ...
# 45471  [{'credit_id': '5894a97d925141426c00818c', 'department': 'Directing', '...
# 45472  [{'credit_id': '52fe4af1c3a36847f81e9b15', 'department': 'Directing', '...
# 45473  [{'credit_id': '52fe4776c3a368484e0c8387', 'department': 'Directing', '...
# 45474  [{'credit_id': '533bccebc3a36844cf0011a7', 'department': 'Directing', '...
# 45475  [{'credit_id': '593e676c92514105b702e68e', 'department': 'Directing', '...
#
#            id
# 0         862
# 1        8844
# 2       15602
# 3       31357
# 4       11862
# ...       ...
# 45471  439050
# 45472  111109
# 45473   67758
# 45474  227506
# 45475  461257
#
# [45476 rows x 3 columns]

# %%
meta = pd.read_csv('movies_metadata.csv')
# Out:
# C:\Users\ajayj\AppData\Local\Temp\ipykernel_9240\2048473160.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta = pd.read_csv('movies_metadata.csv')

# %%
meta.head()
# Out:
#    adult  \
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False
#
#                                                         belongs_to_collection  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915Lf...
# 1                                                                         NaN
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collection', 'poster_path': '/nL...
# 3                                                                         NaN
# 4  {'id': 96871, 'name': 'Father of the Bride Collection', 'poster_path': ...
#
#      budget  \
# 0  30000000
# 1  65000000
# 2         0
# 3  16000000
# 4         0
#
#                                                                        genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': ...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id':...
# 2            [{'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}]
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 1074...
# 4                                              [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                                                      overview  \
# 0  Led by Woody, Andy's toys live happily in his room until Andy's birthda...
# 1  When siblings Judy and Peter discover an enchanted board game that open...
# 2  A family wedding reignites the ancient feud between next-door neighbors...
# 3  Cheated on, mistreated and stepped on, the women are holding their brea...
# 4  Just when George Banks has recovered from his daughter's wedding, he re...
#
#    ... release_date      revenue runtime  \
# 0  ...   1995-10-30  373554033.0    81.0
# 1  ...   1995-12-15  262797249.0   104.0
# 2  ...   1995-12-22          0.0   101.0
# 3  ...   1995-12-22   81452156.0   127.0
# 4  ...   1995-02-10   76578911.0   106.0
#
#                                                              spoken_languages  \
# 0                                    [{'iso_639_1': 'en', 'name': 'English'}]
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'fr', 'name': 'F...
# 2                                    [{'iso_639_1': 'en', 'name': 'English'}]
# 3                                    [{'iso_639_1': 'en', 'name': 'English'}]
# 4                                    [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status  \
# 0  Released
# 1  Released
# 2  Released
# 3  Released
# 4  Released
#
#                                                                       tagline  \
# 0                                                                         NaN
# 1                                   Roll the dice and unleash the excitement!
# 2                        Still Yelling. Still Fighting. Still Ready for Love.
# 3  Friends are the people who let you be yourself... and never let you for...
# 4  Just When His World Is Back To Normal... He's In For The Surprise Of Hi...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
meta['release_date'] = pd.to_datetime(meta['release_date'], errors = 'coerce')

# %%
meta['year'] = meta['release_date'].dt.year

# %%
meta['year'].value_counts().sort_index()
# Out:
# 1874.0       1
# 1878.0       1
# 1883.0       1
# 1887.0       1
# 1888.0       2
#           ...
# 2015.0    1905
# 2016.0    1604
# 2017.0     532
# 2018.0       5
# 2020.0       1
# Name: year, Length: 135, dtype: int64

# %%
new_meta = meta.loc[meta.year <= 2017,['genres', 'id','title','year']]

# %%
new_meta
# Out:
#                                                                            genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': ...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id':...
# 2                [{'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}]
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 1074...
# 4                                                  [{'id': 35, 'name': 'Comedy'}]
# ...                                                                           ...
# 45460  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name': 'Action'}, {'id': 1074...
# 45462                                               [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}, {'id': 53, ...
# 45464                                                                          []
# 45465                                                                          []
#
#            id                        title    year
# 0         862                    Toy Story  1995.0
# 1        8844                      Jumanji  1995.0
# 2       15602             Grumpier Old Men  1995.0
# 3       31357            Waiting to Exhale  1995.0
# 4       11862  Father of the Bride Part II  1995.0
# ...       ...                          ...     ...
# 45460   30840                   Robin Hood  1991.0
# 45462  111109          Century of Birthing  2011.0
# 45463   67758                     Betrayal  2003.0
# 45464  227506             Satan Triumphant  1917.0
# 45465  461257                     Queerama  2017.0
#
# [45370 rows x 4 columns]

# %%
new_meta['id'] = new_meta['id'].astype(int)

# %%
data = pd.merge(new_meta , credits,on = 'id')

# %%
pd.set_option('display.max_colwidth', 75)

# %%
data
# Out:
#                                                                            genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': ...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id':...
# 2                [{'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}]
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 1074...
# 4                                                  [{'id': 35, 'name': 'Comedy'}]
# ...                                                                           ...
# 45440  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name': 'Action'}, {'id': 1074...
# 45441                                               [{'id': 18, 'name': 'Drama'}]
# 45442  [{'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}, {'id': 53, ...
# 45443                                                                          []
# 45444                                                                          []
#
#            id                        title    year  \
# 0         862                    Toy Story  1995.0
# 1        8844                      Jumanji  1995.0
# 2       15602             Grumpier Old Men  1995.0
# 3       31357            Waiting to Exhale  1995.0
# 4       11862  Father of the Bride Part II  1995.0
# ...       ...                          ...     ...
# 45440   30840                   Robin Hood  1991.0
# 45441  111109          Century of Birthing  2011.0
# 45442   67758                     Betrayal  2003.0
# 45443  227506             Satan Triumphant  1917.0
# 45444  461257                     Queerama  2017.0
#
#                                                                              cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)', 'credit_id': '52fe4284c3...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', 'credit_id': '52fe44bfc3a3...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'credit_id': '52fe466a92514...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah' Jackson", 'credit_id': ...
# 4      [{'cast_id': 1, 'character': 'George Banks', 'credit_id': '52fe44959251...
# ...                                                                           ...
# 45440  [{'cast_id': 1, 'character': 'Sir Robert Hode', 'credit_id': '52fe44439...
# 45441  [{'cast_id': 1002, 'character': 'Sister Angela', 'credit_id': '52fe4af1...
# 45442  [{'cast_id': 6, 'character': 'Emily Shaw', 'credit_id': '52fe4776c3a368...
# 45443  [{'cast_id': 2, 'character': '', 'credit_id': '52fe4ea59251416c7515d7d5...
# 45444                                                                          []
#
#                                                                              crew
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'department': 'Directing', '...
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'department': 'Production', ...
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'department': 'Directing', '...
# 3      [{'credit_id': '52fe44779251416c91011acb', 'department': 'Directing', '...
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'department': 'Sound', 'gend...
# ...                                                                           ...
# 45440  [{'credit_id': '52fe44439251416c9100a899', 'department': 'Directing', '...
# 45441  [{'credit_id': '52fe4af1c3a36847f81e9b15', 'department': 'Directing', '...
# 45442  [{'credit_id': '52fe4776c3a368484e0c8387', 'department': 'Directing', '...
# 45443  [{'credit_id': '533bccebc3a36844cf0011a7', 'department': 'Directing', '...
# 45444  [{'credit_id': '593e676c92514105b702e68e', 'department': 'Directing', '...
#
# [45445 rows x 6 columns]

# %%
data['genres'].dtypes
# Out:
# dtype('O')

# %%
import ast
data['genres'] = data['genres'].map(lambda x : ast.literal_eval(x))
data['cast'] = data['cast'].map(lambda x : ast.literal_eval(x))
data['crew'] = data['crew'].map(lambda x : ast.literal_eval(x))

# %%
data['genres'].dtypes
# Out:
# dtype('O')

# %%
def make_genresList(x):
    gen = []
    st = " "
    for i in x:
        if i.get('name') == 'Science Fiction':
            scifi = 'Sci-Fi'
            gen.append(scifi)
        else:
            gen.append(i.get('name'))
    if gen == []:
        return np.NaN
    else:
        return (st.join(gen))

# %%
data['genres_list'] = data['genres'].map(lambda x: make_genresList(x))

# %%
data['genres_list']
# Out:
# 0         Animation Comedy Family
# 1        Adventure Fantasy Family
# 2                  Romance Comedy
# 3            Comedy Drama Romance
# 4                          Comedy
#                    ...
# 45440        Drama Action Romance
# 45441                       Drama
# 45442       Action Drama Thriller
# 45443                         NaN
# 45444                         NaN
# Name: genres_list, Length: 45445, dtype: object

# %%
def get_actor1(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == []:
        return np.NaN
    else:
        return(casts[0])

# %%
data['actor_1_name'] = data['cast'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == [] or len(casts)<=1:
        return np.NaN
    else:
        return(casts[1])

# %%
data['actor_2_name'] = data['cast'].map(lambda x: get_actor2(x))

# %%
data['actor_2_name']
# Out:
# 0                Tim Allen
# 1            Jonathan Hyde
# 2              Jack Lemmon
# 3           Angela Bassett
# 4             Diane Keaton
#                ...
# 45440          Uma Thurman
# 45441          Perry Dizon
# 45442         Adam Baldwin
# 45443    Nathalie Lissenko
# 45444                  NaN
# Name: actor_2_name, Length: 45445, dtype: object

# %%
def get_actor3(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == [] or len(casts)<=2:
        return np.NaN
    else:
        return(casts[2])

# %%
data['actor_3_name'] = data['cast'].map(lambda x: get_actor3(x))

# %%
data['actor_3_name']
# Out:
# 0            Don Rickles
# 1          Kirsten Dunst
# 2            Ann-Margret
# 3         Loretta Devine
# 4           Martin Short
#               ...
# 45440    David Morrissey
# 45441      Hazel Orencio
# 45442      Julie du Page
# 45443       Pavel Pavlov
# 45444                NaN
# Name: actor_3_name, Length: 45445, dtype: object

# %%
def get_directors(x):
    dt = []
    st = " "
    for i in x:
        if i.get('job') == 'Director':
            dt.append(i.get('name'))
    if dt == []:
        return np.NaN
    else:
        return (st.join(dt))

# %%
data['director_name'] = data['crew'].map(lambda x: get_directors(x))

# %%
data['director_name']
# Out:
# 0           John Lasseter
# 1            Joe Johnston
# 2           Howard Deutch
# 3         Forest Whitaker
# 4           Charles Shyer
#                ...
# 45440          John Irvin
# 45441            Lav Diaz
# 45442      Mark L. Lester
# 45443    Yakov Protazanov
# 45444       Daisy Asquith
# Name: director_name, Length: 45445, dtype: object

# %%
movie = data.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres_list','title']]

# %%
movie
# Out:
#           director_name      actor_1_name       actor_2_name     actor_3_name  \
# 0         John Lasseter         Tom Hanks          Tim Allen      Don Rickles
# 1          Joe Johnston    Robin Williams      Jonathan Hyde    Kirsten Dunst
# 2         Howard Deutch    Walter Matthau        Jack Lemmon      Ann-Margret
# 3       Forest Whitaker   Whitney Houston     Angela Bassett   Loretta Devine
# 4         Charles Shyer      Steve Martin       Diane Keaton     Martin Short
# ...                 ...               ...                ...              ...
# 45440        John Irvin    Patrick Bergin        Uma Thurman  David Morrissey
# 45441          Lav Diaz      Angel Aquino        Perry Dizon    Hazel Orencio
# 45442    Mark L. Lester     Erika Eleniak       Adam Baldwin    Julie du Page
# 45443  Yakov Protazanov  Iwan Mosschuchin  Nathalie Lissenko     Pavel Pavlov
# 45444     Daisy Asquith               NaN                NaN              NaN
#
#                     genres_list                        title
# 0       Animation Comedy Family                    Toy Story
# 1      Adventure Fantasy Family                      Jumanji
# 2                Romance Comedy             Grumpier Old Men
# 3          Comedy Drama Romance            Waiting to Exhale
# 4                        Comedy  Father of the Bride Part II
# ...                         ...                          ...
# 45440      Drama Action Romance                   Robin Hood
# 45441                     Drama          Century of Birthing
# 45442     Action Drama Thriller                     Betrayal
# 45443                       NaN             Satan Triumphant
# 45444                       NaN                     Queerama
#
# [45445 rows x 6 columns]

# %%
movie.isna().sum()
# Out:
# director_name     835
# actor_1_name     2354
# actor_2_name     3683
# actor_3_name     4593
# genres_list      2384
# title               0
# dtype: int64

# %%
movie = movie.dropna(how = 'any')

# %%
movie.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres_list      0
# title            0
# dtype: int64

# %%
movie = movie.rename(columns={'genres_list':'genres'})
movie = movie.rename(columns={'title' : 'movie_title'})

# %%
movie['comb'] = movie['actor_1_name'] + ' ' + movie['actor_2_name'] + ' ' + movie['director_name'] +  ' ' + movie['genres']

# %%
movie
# Out:
#          director_name     actor_1_name    actor_2_name     actor_3_name  \
# 0        John Lasseter        Tom Hanks       Tim Allen      Don Rickles
# 1         Joe Johnston   Robin Williams   Jonathan Hyde    Kirsten Dunst
# 2        Howard Deutch   Walter Matthau     Jack Lemmon      Ann-Margret
# 3      Forest Whitaker  Whitney Houston  Angela Bassett   Loretta Devine
# 4        Charles Shyer     Steve Martin    Diane Keaton     Martin Short
# ...                ...              ...             ...              ...
# 45438         Ben Rock       Monty Bane     Lucy Butler    David Grammer
# 45439    Aaron Osborne       Lisa Boyle       Kena Land    Zaneta Polard
# 45440       John Irvin   Patrick Bergin     Uma Thurman  David Morrissey
# 45441         Lav Diaz     Angel Aquino     Perry Dizon    Hazel Orencio
# 45442   Mark L. Lester    Erika Eleniak    Adam Baldwin    Julie du Page
#
#                          genres                  movie_title  \
# 0       Animation Comedy Family                    Toy Story
# 1      Adventure Fantasy Family                      Jumanji
# 2                Romance Comedy             Grumpier Old Men
# 3          Comedy Drama Romance            Waiting to Exhale
# 4                        Comedy  Father of the Bride Part II
# ...                         ...                          ...
# 45438                    Horror          The Burkittsville 7
# 45439                    Sci-Fi              Caged Heat 3000
# 45440      Drama Action Romance                   Robin Hood
# 45441                     Drama          Century of Birthing
# 45442     Action Drama Thriller                     Betrayal
#
#                                                                       comb
# 0                Tom Hanks Tim Allen John Lasseter Animation Comedy Family
# 1       Robin Williams Jonathan Hyde Joe Johnston Adventure Fantasy Family
# 2                  Walter Matthau Jack Lemmon Howard Deutch Romance Comedy
# 3      Whitney Houston Angela Bassett Forest Whitaker Comedy Drama Romance
# 4                           Steve Martin Diane Keaton Charles Shyer Comedy
# ...                                                                    ...
# 45438                               Monty Bane Lucy Butler Ben Rock Horror
# 45439                            Lisa Boyle Kena Land Aaron Osborne Sci-Fi
# 45440           Patrick Bergin Uma Thurman John Irvin Drama Action Romance
# 45441                              Angel Aquino Perry Dizon Lav Diaz Drama
# 45442      Erika Eleniak Adam Baldwin Mark L. Lester Action Drama Thriller
#
# [39201 rows x 7 columns]

# %%
movie.to_csv('movie.csv',index = False)
